# %% [markdown]
# # Using pandas

# %%
import pandas as pd
import numpy as np # for generating random numbers

# %% [markdown]
# ## Series

# %%
# series
s1 = pd.Series([10, 11, 12], dtype = float)
s1
# Out:
# 0    10.0
# 1    11.0
# 2    12.0
# dtype: float64

# %%
s2 = pd.Series([10, 11, 12], dtype = int)
s2
# Out:
# 0    10
# 1    11
# 2    12
# dtype: int64

# %%
s3 = pd.Series(["10", "11", "12"], name = 'Val', index = pd.Index(['a', 'b', 'c'], name = 'label'))
s3
# Out:
# label
# a    10
# b    11
# c    12
# Name: Val, dtype: object

# %%
s1.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# s1.append(s2)
pd.concat([s1, s3])
s4
# Out:
# 0    10.0
# 1    11.0
# 2    12.0
# a      10
# b      11
# c      12
# dtype: object

# %%
print(s4[0])
print(s4)
s4_reset = s4.reset_index(drop=True)
print(s4_reset)
s4_reset[0]
# Out:
# 10.0
# 0    10.0
# 1    11.0
# 2    12.0
# a      10
# b      11
# c      12
# dtype: object
# 0    10.0
# 1    11.0
# 2    12.0
# 3      10
# 4      11
# 5      12
# dtype: object
# 10.0

# %%
dates = pd.date_range('20190503', periods=7)

dates
# Out:
# DatetimeIndex(['2019-05-03', '2019-05-04', '2019-05-05', '2019-05-06',
#                '2019-05-07', '2019-05-08', '2019-05-09'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame(np.random.randn(7, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2019-05-03  0.742865  1.470340  0.309670  2.139395
# 2019-05-04 -0.329849 -0.385884 -0.406736  2.294547
# 2019-05-05  1.085329 -0.209297 -0.905707  1.780334
# 2019-05-06 -1.099450  0.587316 -0.507449  2.373807
# 2019-05-07  0.333924 -0.122433 -0.313601 -0.887003
# 2019-05-08 -0.352286 -1.137880  0.247627  1.095548
# 2019-05-09 -1.228849 -1.565496 -1.537623  1.695860

# %%
df2 = pd.DataFrame({'A': 1.,
                    'B': pd.Timestamp('20130102'),
                    'C': pd.Series(1, index=list(range(2, 6)), dtype='float32'),
                    'D': np.array([3] * 4, dtype='int32'),
                    'E': pd.Categorical(["test", "train", "test", "train"]),
                    'F': 'foo'})
df2
# Out:
#      A          B    C  D      E    F
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# 4  1.0 2013-01-02  1.0  3   test  foo
# 5  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %% [markdown]
# ## Viewing Data

# %%
df.head(10)
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
# 5           6   56    1    nontypical     120   236    0        0    178
# 6           7   62    0  asymptomatic     140   268    0        2    160
# 7           8   57    0  asymptomatic     120   354    0        0    163
# 8           9   63    1  asymptomatic     130   254    0        2    147
# 9          10   53    1  asymptomatic     140   203    1        2    155
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No
# 5      0      0.8      1  0.0      normal   No
# 6      0      3.6      3  2.0      normal  Yes
# 7      1      0.6      1  0.0      normal   No
# 8      0      1.4      2  1.0  reversable  Yes
# 9      1      3.1      3  0.0  reversable  Yes

# %%
df.tail(8)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 295         296   41    1    nontypical     120   157    0        0    182
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 297         298   57    0  asymptomatic     140   241    0        0    123
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 295      0      0.0      1  0.0      normal   No
# 296      0      1.0      2  2.0       fixed  Yes
# 297      1      0.2      2  0.0  reversable  Yes
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# std      0.994971   22.875003    0.469794    1.161075    0.616226    0.937438
# min      0.000000   71.000000    0.000000    0.000000    1.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000    3.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
# df.sort_index(axis=0, ascending=True)
# df.sort_index(axis=0, ascending=False)

df.sort_index(axis=1, ascending=True)
df.sort_index(axis=1, ascending=False)
# Out:
#      Unnamed: 0        Thal  Slope  Sex  RestECG  RestBP  Oldpeak  MaxHR  Fbs  \
# 0             1       fixed      3    1        2     145      2.3    150    1
# 1             2      normal      2    1        2     160      1.5    108    0
# 2             3  reversable      2    1        2     120      2.6    129    0
# 3             4      normal      3    1        0     130      3.5    187    0
# 4             5      normal      1    0        2     130      1.4    172    0
# ..          ...         ...    ...  ...      ...     ...      ...    ...  ...
# 298         299  reversable      2    1        0     110      1.2    132    0
# 299         300  reversable      2    1        0     144      3.4    141    1
# 300         301  reversable      2    1        0     130      1.2    115    0
# 301         302      normal      2    0        2     130      0.0    174    0
# 302         303      normal      1    1        0     138      0.0    173    0
#
#      ExAng  Chol     ChestPain   Ca  Age  AHD
# 0        0   233       typical  0.0   63   No
# 1        1   286  asymptomatic  3.0   67  Yes
# 2        1   229  asymptomatic  2.0   67  Yes
# 3        0   250    nonanginal  0.0   37   No
# 4        0   204    nontypical  0.0   41   No
# ..     ...   ...           ...  ...  ...  ...
# 298      0   264       typical  0.0   45  Yes
# 299      0   193  asymptomatic  2.0   68  Yes
# 300      1   131  asymptomatic  1.0   57  Yes
# 301      0   236    nontypical  1.0   57  Yes
# 302      0   175    nonanginal  NaN   38   No
#
# [303 rows x 15 columns]

# %%
df.sort_values(by = 'Sex', ascending = False)
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 205         206   45    1  asymptomatic     142   309    0        2    147
# 161         162   77    1  asymptomatic     125   304    0        2    162
# 164         165   48    1    nonanginal     124   255    1        0    175
# 165         166   57    1  asymptomatic     132   207    0        0    168
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 197         198   45    0  asymptomatic     138   236    0        2    152
# 194         195   68    0    nonanginal     120   211    0        2    115
# 193         194   62    0  asymptomatic     138   294    1        0    106
# 70           71   65    0    nonanginal     155   269    0        0    148
# 151         152   42    0  asymptomatic     102   265    0        2    122
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 205      1      0.0      2  3.0  reversable  Yes
# 161      1      0.0      1  3.0      normal  Yes
# 164      0      0.0      1  2.0      normal   No
# 165      1      0.0      1  0.0  reversable   No
# ..     ...      ...    ...  ...         ...  ...
# 197      1      0.2      2  0.0      normal   No
# 194      0      1.5      2  0.0      normal   No
# 193      0      1.9      2  3.0      normal  Yes
# 70       0      0.8      1  0.0      normal   No
# 151      0      0.6      2  0.0      normal   No
#
# [303 rows x 15 columns]

# %%
df.T
# Out:
#                 0             1             2           3           4    \
# Unnamed: 0        1             2             3           4           5
# Age              63            67            67          37          41
# Sex               1             1             1           1           0
# ChestPain   typical  asymptomatic  asymptomatic  nonanginal  nontypical
# RestBP          145           160           120         130         130
# Chol            233           286           229         250         204
# Fbs               1             0             0           0           0
# RestECG           2             2             2           0           2
# MaxHR           150           108           129         187         172
# ExAng             0             1             1           0           0
# Oldpeak         2.3           1.5           2.6         3.5         1.4
# Slope             3             2             2           3           1
# Ca              0.0           3.0           2.0         0.0         0.0
# Thal          fixed        normal    reversable      normal      normal
# AHD              No           Yes           Yes          No          No
#
#                    5             6             7             8    \
# Unnamed: 0           6             7             8             9
# Age                 56            62            57            63
# Sex                  1             0             0             1
# ChestPain   nontypical  asymptomatic  asymptomatic  asymptomatic
# RestBP             120           140           120           130
# Chol               236           268           354           254
# Fbs                  0             0             0             0
# RestECG              0             2             0             2
# MaxHR              178           160           163           147
# ExAng                0             0             1             0
# Oldpeak            0.8           3.6           0.6           1.4
# Slope                1             3             1             2
# Ca                 0.0           2.0           0.0           1.0
# Thal            normal        normal        normal    reversable
# AHD                 No           Yes            No           Yes
#
#                      9    ...           293           294         295  \
# Unnamed: 0            10  ...           294           295         296
# Age                   53  ...            63            63          41
# Sex                    1  ...             1             0           1
# ChestPain   asymptomatic  ...  asymptomatic  asymptomatic  nontypical
# RestBP               140  ...           140           124         120
# Chol                 203  ...           187           197         157
# Fbs                    1  ...             0             0           0
# RestECG                2  ...             2             0           0
# MaxHR                155  ...           144           136         182
# ExAng                  1  ...             1             1           0
# Oldpeak              3.1  ...           4.0           0.0         0.0
# Slope                  3  ...             1             2           1
# Ca                   0.0  ...           2.0           0.0         0.0
# Thal          reversable  ...    reversable        normal      normal
# AHD                  Yes  ...           Yes           Yes          No
#
#                      296           297         298           299  \
# Unnamed: 0           297           298         299           300
# Age                   59            57          45            68
# Sex                    1             0           1             1
# ChestPain   asymptomatic  asymptomatic     typical  asymptomatic
# RestBP               164           140         110           144
# Chol                 176           241         264           193
# Fbs                    1             0           0             1
# RestECG                2             0           0             0
# MaxHR                 90           123         132           141
# ExAng                  0             1           0             0
# Oldpeak              1.0           0.2         1.2           3.4
# Slope                  2             2           2             2
# Ca                   2.0           0.0         0.0           2.0
# Thal               fixed    reversable  reversable    reversable
# AHD                  Yes           Yes         Yes           Yes
#
#                      300         301         302
# Unnamed: 0           301         302         303
# Age                   57          57          38
# Sex                    1           0           1
# ChestPain   asymptomatic  nontypical  nonanginal
# RestBP               130         130         138
# Chol                 131         236         175
# Fbs                    0           0           0
# RestECG                0           2           0
# MaxHR                115         174         173
# ExAng                  1           0           0
# Oldpeak              1.2         0.0         0.0
# Slope                  2           2           1
# Ca                   1.0         1.0         NaN
# Thal          reversable      normal      normal
# AHD                  Yes         Yes          No
#
# [15 rows x 303 columns]

# %%
df['Age']
# Out:
# 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: Age, Length: 303, dtype: int64

# %%
df[['Age', 'Sex']]
# Out:
#      Age  Sex
# 0     63    1
# 1     67    1
# 2     67    1
# 3     37    1
# 4     41    0
# ..   ...  ...
# 298   45    1
# 299   68    1
# 300   57    1
# 301   57    0
# 302   38    1
#
# [303 rows x 2 columns]

# %%
df[['Age', 'Sex']][0:2]
# Out:
#    Age  Sex
# 0   63    1
# 1   67    1

# %%
df[0:2][['Age']]
# Out:
#    Age
# 0   63
# 1   67

# %% [markdown]
# ## Data Selection

# %%
df.loc[4]
# df
# Out:
# Unnamed: 0             5
# Age                   41
# Sex                    0
# ChestPain     nontypical
# RestBP               130
# Chol                 204
# Fbs                    0
# RestECG                2
# MaxHR                172
# ExAng                  0
# Oldpeak              1.4
# Slope                  1
# Ca                   0.0
# Thal              normal
# AHD                   No
# Name: 4, dtype: object

# %%
df.loc[[3,5], ['Age', 'Fbs']]
# Out:
#    Age  Fbs
# 3   37    0
# 5   56    0

# %%
df.iloc[5]
# Out:
# Unnamed: 0             6
# Age                   56
# Sex                    1
# ChestPain     nontypical
# RestBP               120
# Chol                 236
# Fbs                    0
# RestECG                0
# MaxHR                178
# ExAng                  0
# Oldpeak              0.8
# Slope                  1
# Ca                   0.0
# Thal              normal
# AHD                   No
# Name: 5, dtype: object

# %%
df.iloc[5, 3]
# Out:
# 'nontypical'

# %%
# df.iloc[5:7, 3:7]
# df.iloc[[5, 7, 9], 3:7]
# df.iloc[:, 3]
df.iloc[3: 5, :]
# df.loc[5:7, 3:7]
# Out:
#    Unnamed: 0  Age  Sex   ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 3           4   37    1  nonanginal     130   250    0        0    187      0
# 4           5   41    0  nontypical     130   204    0        2    172      0
#
#    Oldpeak  Slope   Ca    Thal AHD
# 3      3.5      3  0.0  normal  No
# 4      1.4      1  0.0  normal  No

# %%
df.iloc[1, 1]
df.at[1, 'Age'] # Get scalar values. It's a very fast loc
df.iat[1, 1] # Get scalar values. It's a very fast iloc
# Out:
# 67

# %%
df['Age'] > 50
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 298    False
# 299     True
# 300     True
# 301     True
# 302    False
# Name: Age, Length: 303, dtype: bool

# %%
df[df.Age > 50]
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 5             6   56    1    nontypical     120   236    0        0    178
# 6             7   62    0  asymptomatic     140   268    0        2    160
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 296         297   59    1  asymptomatic     164   176    1        2     90
# 297         298   57    0  asymptomatic     140   241    0        0    123
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 5        0      0.8      1  0.0      normal   No
# 6        0      3.6      3  2.0      normal  Yes
# ..     ...      ...    ...  ...         ...  ...
# 296      0      1.0      2  2.0       fixed  Yes
# 297      1      0.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
#
# [209 rows x 15 columns]

# %%
df2 = df.copy()
df2 = df2.iloc[0: 5, :]
df2
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
# dfa['A'] = list(range(len(dfa.index)))  # use this form to create a new column
df2['cp'] = ['three', 'two', 'one', 'one', 'zero']
df2
df2.cp.isin(['one', 'zero'])
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: cp, dtype: bool

# %%
df2[df2.cp.isin(['one', 'zero'])]
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD    cp
# 2      1      2.6      2  2.0  reversable  Yes   one
# 3      0      3.5      3  0.0      normal   No   one
# 4      0      1.4      1  0.0      normal   No  zero

# %% [markdown]
# ## Missing Data

# %%
df1 = df.reindex(index=range(0, 4), columns=list(df.columns) + ['E'])
df1.loc[2:3, 'E'] = 1
df1
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD    E
# 0      0      2.3      3  0.0       fixed   No  NaN
# 1      1      1.5      2  3.0      normal  Yes  NaN
# 2      1      2.6      2  2.0  reversable  Yes  1.0
# 3      0      3.5      3  0.0      normal   No  1.0

# %%
df1.dropna(how='any')
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD    E
# 2      1      2.6      2  2.0  reversable  Yes  1.0
# 3      0      3.5      3  0.0      normal   No  1.0

# %%
pd.isna(df1)
# Out:
#    Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  MaxHR  \
# 0       False  False  False      False   False  False  False    False  False
# 1       False  False  False      False   False  False  False    False  False
# 2       False  False  False      False   False  False  False    False  False
# 3       False  False  False      False   False  False  False    False  False
#
#    ExAng  Oldpeak  Slope     Ca   Thal    AHD      E
# 0  False    False  False  False  False  False   True
# 1  False    False  False  False  False  False   True
# 2  False    False  False  False  False  False  False
# 3  False    False  False  False  False  False  False

# %%
df1.fillna(value=2)
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD    E
# 0      0      2.3      3  0.0       fixed   No  2.0
# 1      1      1.5      2  3.0      normal  Yes  2.0
# 2      1      2.6      2  2.0  reversable  Yes  1.0
# 3      0      3.5      3  0.0      normal   No  1.0

# %% [markdown]
# ## Operations

# %%
df1.mean()
# Out:
# /tmp/ipykernel_45469/2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# Unnamed: 0      2.500
# Age            58.500
# Sex             1.000
# RestBP        138.750
# Chol          249.500
# Fbs             0.250
# RestECG         1.500
# MaxHR         143.500
# ExAng           0.500
# Oldpeak         2.475
# Slope           2.500
# Ca              1.250
# E               1.000
# dtype: float64

# %%
df1.mean(axis = 1)
# Out:
# /tmp/ipykernel_45469/3704246674.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean(axis = 1)
# 0    50.108333
# 1    52.791667
# 2    43.046154
# 3    47.423077
# dtype: float64

# %%
# df1.sub([10 for _ in range(4)], axis = 'index')
df1.mul([10 for _ in range(4)], axis = 'index')
# Out:
#    Unnamed: 0  Age  Sex                                          ChestPain  \
# 0          10  630   10  typicaltypicaltypicaltypicaltypicaltypicaltypi...
# 1          20  670   10  asymptomaticasymptomaticasymptomaticasymptomat...
# 2          30  670   10  asymptomaticasymptomaticasymptomaticasymptomat...
# 3          40  370   10  nonanginalnonanginalnonanginalnonanginalnonang...
#
#    RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope    Ca  \
# 0    1450  2330   10       20   1500      0     23.0     30   0.0
# 1    1600  2860    0       20   1080     10     15.0     20  30.0
# 2    1200  2290    0       20   1290     10     26.0     20  20.0
# 3    1300  2500    0        0   1870      0     35.0     30   0.0
#
#                                                 Thal  \
# 0  fixedfixedfixedfixedfixedfixedfixedfixedfixedf...
# 1  normalnormalnormalnormalnormalnormalnormalnorm...
# 2  reversablereversablereversablereversablerevers...
# 3  normalnormalnormalnormalnormalnormalnormalnorm...
#
#                               AHD     E
# 0            NoNoNoNoNoNoNoNoNoNo   NaN
# 1  YesYesYesYesYesYesYesYesYesYes   NaN
# 2  YesYesYesYesYesYesYesYesYesYes  10.0
# 3            NoNoNoNoNoNoNoNoNoNo  10.0

# %%
df1
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD    E
# 0      0      2.3      3  0.0       fixed   No  NaN
# 1      1      1.5      2  3.0      normal  Yes  NaN
# 2      1      2.6      2  2.0  reversable  Yes  1.0
# 3      0      3.5      3  0.0      normal   No  1.0

# %%
df1.apply(np.cumsum)
# Out:
#    Unnamed: 0  Age  Sex                                  ChestPain  RestBP  \
# 0           1   63    1                                    typical     145
# 1           3  130    2                        typicalasymptomatic     305
# 2           6  197    3            typicalasymptomaticasymptomatic     425
# 3          10  234    4  typicalasymptomaticasymptomaticnonanginal     555
#
#    Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  Slope   Ca  \
# 0   233    1        2    150      0      2.3      3  0.0
# 1   519    1        4    258      1      3.8      5  3.0
# 2   748    1        6    387      2      6.4      7  5.0
# 3   998    1        6    574      2      9.9     10  5.0
#
#                           Thal         AHD    E
# 0                        fixed          No  NaN
# 1                  fixednormal       NoYes  NaN
# 2        fixednormalreversable    NoYesYes  1.0
# 3  fixednormalreversablenormal  NoYesYesNo  2.0

# %%
df1.Age.apply(lambda x: x*365.25)
# Out:
# 0    23010.75
# 1    24471.75
# 2    24471.75
# 3    13514.25
# Name: Age, dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    1
# 1    5
# 2    3
# 3    6
# 4    6
# 5    3
# 6    0
# 7    5
# 8    3
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    3
# 1    2
# 5    2
# 6    2
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
s
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# ## Merge

# %%
df2 = pd.DataFrame(np.random.randn(10, 4))
pieces = [df2[:3], df2[3:7], df2[7:]]

pieces

pd.concat([pieces[2], pieces[1], pieces[0]])
# Out:
#           0         1         2         3
# 7  0.855656  0.433703  0.889092  0.186861
# 8  1.192116  1.280626 -0.031879  0.708394
# 9  0.771815  0.493390  0.787082 -0.410764
# 3  0.542291  1.029881  1.356394  0.517427
# 4  1.390097 -1.789493  0.926653  0.286425
# 5 -0.601276 -1.186965 -0.480340  0.894742
# 6 -0.750025  1.734699  0.903438 -1.255214
# 0 -0.019683  0.679008  0.852743  0.008892
# 1  1.101362 -1.681867 -0.762357  1.375896
# 2 -1.127409 -0.430024 -0.227392 -1.388213

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
# df.append(df.iloc[3])
df.append(df.iloc[3], ignore_index = True)
# Out:
# /tmp/ipykernel_45469/2883249601.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df.iloc[3], ignore_index = True)
#           A         B         C         D
# 0 -0.082480  0.523990 -2.139957  1.105579
# 1  0.631295  0.291481 -0.209872 -1.489623
# 2 -0.357730  0.493279 -1.169207 -1.135050
# 3  0.579116  1.714910 -0.205782  1.162658
# 4  0.236897  0.022318  0.062660  0.769803
# 5 -0.430482 -1.351782 -0.509274  1.033734
# 6  0.515732 -0.517902  0.249512  0.633524
# 7 -1.377213  1.584660 -0.970422 -0.449719
# 8  0.579116  1.714910 -0.205782  1.162658

# %% [markdown]
# ## Grouping

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                    'foo', 'bar', 'foo', 'foo'],
                    'B': ['one', 'one', 'two', 'three',
                    'two', 'two', 'one', 'three'],
                    'C': np.random.randn(8),
                    'D': np.random.randn(8)})

df
# Out:
#      A      B         C         D
# 0  foo    one -0.604120  1.103890
# 1  bar    one -0.830004  0.533205
# 2  foo    two  0.552945  0.681709
# 3  bar  three  1.083474 -1.175398
# 4  foo    two -0.049033  0.027573
# 5  bar    two -1.287016  0.638788
# 6  foo    one -0.173131  0.182642
# 7  foo  three  0.197809 -0.789831

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -1.033546 -0.003405
# foo -0.075531  1.205984

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.830004  0.533205
#     three  1.083474 -1.175398
#     two   -1.287016  0.638788
# foo one   -0.777251  1.286532
#     three  0.197809 -0.789831
#     two    0.503911  0.709283

# %% [markdown]
# ## Plotting

# %%
df.groupby('A').sum()['C'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True);

# %%
df2.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## File I/O

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df.to_csv('heart_copy.csv', index = False)

# %%
df1 = df[:10]
df2 = df[10:20]
df3 = df[20:40]

# %%
# with pd.ExcelWriter('path_to_file.xlsx') as writer:
#     df1.to_excel(writer, sheet_name='Sheet1', index = False)
#     df2.to_excel(writer, sheet_name='Sheet2', index = False)
#     df3.to_excel(writer, sheet_name='Sheet3')
